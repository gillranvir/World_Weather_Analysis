# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key2
key = weather_api_key2

# %%
# Starting URL for weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?&appid="+ key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})
                      
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | umm kaddadah
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | pangnirtung
# Processing Record 4 of Set 1 | rio grande
# Processing Record 5 of Set 1 | dzerzhinskoye
# Processing Record 6 of Set 1 | southampton
# Processing Record 7 of Set 1 | sakakah
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | masindi
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | burnie
# Processing Record 12 of Set 1 | levokumka
# Processing Record 13 of Set 1 | sawtell
# Processing Record 14 of Set 1 | caravelas
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | ostrovnoy
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | alugan
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | pangai
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 1 | teguise
# Processing Record 26 of Set 1 | college
# Processing Record 27 of Set 1 | xingcheng
# Processing Record 28 of Set 1 | buriti alegre
# Processing Record 29 of Set 1 | general roca
# Processing Record 30 of Set 1 | mukhen
# Processing Record 31 of Set 1 | xingyi
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | saint-augustin
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | loandjili
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | san quintin
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | jiangyou
# Processing Record 41 of Set 1 | kondopoga
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | tiznit
# Processing Record 44 of Set 1 | matara
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 1 | tak bai
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | zwedru
# Processing Record 50 of Set 1 | vila do maio
# Processing Record 1 of Set 2 | nelson bay
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | cairns
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | belomorsk
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | harnai
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | nuuk
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | nenjiang
# Processing Record 15 of Set 2 | port lincoln
# Processing Record 16 of Set 2 | lezhe
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | odweyne
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | iquitos
# Processing Record 22 of Set 2 | alibag
# Processing Record 23 of Set 2 | sabaudia
# Processing Record 24 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | haines junction
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | puerto baquerizo moreno
# Processing Record 31 of Set 2 | conceicao do araguaia
# Processing Record 32 of Set 2 | gunjur
# Processing Record 33 of Set 2 | cheney
# Processing Record 34 of Set 2 | komsomolskiy
# Processing Record 35 of Set 2 | akyab
# Processing Record 36 of Set 2 | pasni
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | adrar
# Processing Record 40 of Set 2 | aklavik
# Processing Record 41 of Set 2 | baiyin
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | vitimskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | lazaro cardenas
# Processing Record 45 of Set 2 | naifaru
# Processing Record 46 of Set 2 | jasper
# Processing Record 47 of Set 2 | talara
# Processing Record 48 of Set 2 | yar-sale
# Processing Record 49 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 2 | zalantun
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | podyuga
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | lorengau
# Processing Record 5 of Set 3 | namatanai
# Processing Record 6 of Set 3 | nouadhibou
# Processing Record 7 of Set 3 | alyangula
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | batyrevo
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | kaeo
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | san policarpo
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | cidreira
# Processing Record 16 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | riachao das neves
# Processing Record 19 of Set 3 | atambua
# Processing Record 20 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 3 | itarema
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | half moon bay
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | mar del plata
# Processing Record 26 of Set 3 | shingu
# Processing Record 27 of Set 3 | lalibela
# Processing Record 28 of Set 3 | wahiawa
# Processing Record 29 of Set 3 | springdale
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | fortuna
# Processing Record 33 of Set 3 | pochutla
# Processing Record 34 of Set 3 | arlit
# Processing Record 35 of Set 3 | liverpool
# Processing Record 36 of Set 3 | bay roberts
# Processing Record 37 of Set 3 | ilulissat
# Processing Record 38 of Set 3 | waipawa
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | midland
# Processing Record 41 of Set 3 | bina-etawa
# City not found. Skipping...
# Processing Record 42 of Set 3 | alta floresta
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | fuyu
# Processing Record 45 of Set 3 | dali
# Processing Record 46 of Set 3 | benghazi
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | srednekolymsk
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | oriximina
# Processing Record 1 of Set 4 | bekhtery
# Processing Record 2 of Set 4 | samana
# Processing Record 3 of Set 4 | bengkulu
# Processing Record 4 of Set 4 | vardo
# Processing Record 5 of Set 4 | toungoo
# City not found. Skipping...
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | lavrentiya
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | lokosovo
# Processing Record 10 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 4 | chicama
# Processing Record 12 of Set 4 | nuevitas
# Processing Record 13 of Set 4 | mayor pablo lagerenza
# Processing Record 14 of Set 4 | nichinan
# Processing Record 15 of Set 4 | maniitsoq
# Processing Record 16 of Set 4 | nome
# Processing Record 17 of Set 4 | vaini
# Processing Record 18 of Set 4 | teacapan
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | yongan
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | mariel
# Processing Record 23 of Set 4 | biograd na moru
# Processing Record 24 of Set 4 | roebourne
# Processing Record 25 of Set 4 | paamiut
# Processing Record 26 of Set 4 | northam
# Processing Record 27 of Set 4 | gumdag
# Processing Record 28 of Set 4 | atyashevo
# Processing Record 29 of Set 4 | york
# Processing Record 30 of Set 4 | cayenne
# Processing Record 31 of Set 4 | kamenka
# Processing Record 32 of Set 4 | semey
# Processing Record 33 of Set 4 | jaguaruna
# Processing Record 34 of Set 4 | richards bay
# Processing Record 35 of Set 4 | soe
# Processing Record 36 of Set 4 | ossora
# Processing Record 37 of Set 4 | zarubino
# Processing Record 38 of Set 4 | vao
# Processing Record 39 of Set 4 | rudbar
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 4 | mizdah
# Processing Record 43 of Set 4 | dikson
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | tadine
# Processing Record 46 of Set 4 | kirakira
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | solnechnyy
# Processing Record 49 of Set 4 | pimenta bueno
# Processing Record 50 of Set 4 | warangal
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | yamethin
# Processing Record 3 of Set 5 | port hedland
# Processing Record 4 of Set 5 | baruun-urt
# Processing Record 5 of Set 5 | naze
# Processing Record 6 of Set 5 | namibe
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | amuntai
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | vestmanna
# Processing Record 11 of Set 5 | gorele
# Processing Record 12 of Set 5 | hamilton
# Processing Record 13 of Set 5 | constitucion
# Processing Record 14 of Set 5 | longyearbyen
# Processing Record 15 of Set 5 | gao
# Processing Record 16 of Set 5 | valdosta
# Processing Record 17 of Set 5 | vestmannaeyjar
# Processing Record 18 of Set 5 | peterborough
# Processing Record 19 of Set 5 | quatre cocos
# Processing Record 20 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 5 | lamu
# Processing Record 22 of Set 5 | sobolevo
# Processing Record 23 of Set 5 | huanren
# Processing Record 24 of Set 5 | kontagora
# Processing Record 25 of Set 5 | khorol
# Processing Record 26 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 5 | santa cruz
# Processing Record 28 of Set 5 | sao jose da coroa grande
# Processing Record 29 of Set 5 | mandalgovi
# Processing Record 30 of Set 5 | garden city
# Processing Record 31 of Set 5 | kilindoni
# Processing Record 32 of Set 5 | fairbanks
# Processing Record 33 of Set 5 | kimbe
# Processing Record 34 of Set 5 | beringovskiy
# Processing Record 35 of Set 5 | russell
# Processing Record 36 of Set 5 | souillac
# Processing Record 37 of Set 5 | lephepe
# City not found. Skipping...
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | baykit
# Processing Record 40 of Set 5 | bovolone
# Processing Record 41 of Set 5 | qaanaaq
# Processing Record 42 of Set 5 | bure
# Processing Record 43 of Set 5 | te anau
# Processing Record 44 of Set 5 | porto novo
# Processing Record 45 of Set 5 | jishou
# Processing Record 46 of Set 5 | sitka
# Processing Record 47 of Set 5 | oksfjord
# Processing Record 48 of Set 5 | akom
# Processing Record 49 of Set 5 | port arthur
# Processing Record 50 of Set 5 | gravenhurst
# Processing Record 1 of Set 6 | pevek
# Processing Record 2 of Set 6 | dalhousie
# Processing Record 3 of Set 6 | rusape
# Processing Record 4 of Set 6 | esperance
# Processing Record 5 of Set 6 | kokopo
# Processing Record 6 of Set 6 | tucuman
# Processing Record 7 of Set 6 | khatanga
# Processing Record 8 of Set 6 | villarrobledo
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | da lat
# Processing Record 11 of Set 6 | general elizardo aquino
# Processing Record 12 of Set 6 | tuktoyaktuk
# Processing Record 13 of Set 6 | kahului
# Processing Record 14 of Set 6 | bosaso
# Processing Record 15 of Set 6 | carman
# Processing Record 16 of Set 6 | mingaora
# Processing Record 17 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 6 | mokhsogollokh
# Processing Record 19 of Set 6 | rudraprayag
# Processing Record 20 of Set 6 | ilhabela
# Processing Record 21 of Set 6 | pisco
# Processing Record 22 of Set 6 | snyder
# Processing Record 23 of Set 6 | panaba
# Processing Record 24 of Set 6 | thompson
# Processing Record 25 of Set 6 | maku
# Processing Record 26 of Set 6 | livingstonia
# Processing Record 27 of Set 6 | flinders
# Processing Record 28 of Set 6 | ust-ordynskiy
# Processing Record 29 of Set 6 | iqaluit
# Processing Record 30 of Set 6 | bethel
# Processing Record 31 of Set 6 | chulumani
# Processing Record 32 of Set 6 | sal rei
# Processing Record 33 of Set 6 | coruripe
# Processing Record 34 of Set 6 | asmara
# Processing Record 35 of Set 6 | mahibadhoo
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | vila
# Processing Record 38 of Set 6 | arraial do cabo
# Processing Record 39 of Set 6 | kothapet
# Processing Record 40 of Set 6 | luanda
# Processing Record 41 of Set 6 | anadyr
# Processing Record 42 of Set 6 | chunskiy
# Processing Record 43 of Set 6 | kenai
# Processing Record 44 of Set 6 | tortoli
# Processing Record 45 of Set 6 | hasaki
# Processing Record 46 of Set 6 | kinrooi
# Processing Record 47 of Set 6 | maldonado
# Processing Record 48 of Set 6 | airai
# Processing Record 49 of Set 6 | manggar
# Processing Record 50 of Set 6 | ketchikan
# Processing Record 1 of Set 7 | makakilo city
# Processing Record 2 of Set 7 | abu dhabi
# Processing Record 3 of Set 7 | tautira
# Processing Record 4 of Set 7 | fort nelson
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | taltal
# Processing Record 7 of Set 7 | ancud
# Processing Record 8 of Set 7 | helena
# Processing Record 9 of Set 7 | damphu
# Processing Record 10 of Set 7 | senador jose porfirio
# Processing Record 11 of Set 7 | mapiripan
# Processing Record 12 of Set 7 | beloha
# Processing Record 13 of Set 7 | sept-iles
# Processing Record 14 of Set 7 | nishihara
# Processing Record 15 of Set 7 | gojra
# Processing Record 16 of Set 7 | victoria
# Processing Record 17 of Set 7 | moussoro
# Processing Record 18 of Set 7 | straumen
# Processing Record 19 of Set 7 | torit
# Processing Record 20 of Set 7 | meleuz
# Processing Record 21 of Set 7 | dalian
# Processing Record 22 of Set 7 | juneau
# Processing Record 23 of Set 7 | marsh harbour
# Processing Record 24 of Set 7 | uyemskiy
# Processing Record 25 of Set 7 | pacifica
# Processing Record 26 of Set 7 | cabo san lucas
# Processing Record 27 of Set 7 | xai-xai
# Processing Record 28 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 7 | vredendal
# Processing Record 30 of Set 7 | ulm
# Processing Record 31 of Set 7 | at-bashi
# Processing Record 32 of Set 7 | launceston
# Processing Record 33 of Set 7 | comodoro rivadavia
# Processing Record 34 of Set 7 | kyra
# Processing Record 35 of Set 7 | saskylakh
# Processing Record 36 of Set 7 | rundu
# Processing Record 37 of Set 7 | malanje
# Processing Record 38 of Set 7 | kavaratti
# Processing Record 39 of Set 7 | atar
# Processing Record 40 of Set 7 | macaubas
# Processing Record 41 of Set 7 | isangel
# Processing Record 42 of Set 7 | dingle
# Processing Record 43 of Set 7 | gat
# Processing Record 44 of Set 7 | madinat sittah uktubar
# Processing Record 45 of Set 7 | methoni
# Processing Record 46 of Set 7 | huarmey
# Processing Record 47 of Set 7 | nhulunbuy
# Processing Record 48 of Set 7 | svetlyy
# Processing Record 49 of Set 7 | fatsa
# Processing Record 50 of Set 7 | morondava
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | evanston
# Processing Record 3 of Set 8 | morant bay
# Processing Record 4 of Set 8 | arvika
# Processing Record 5 of Set 8 | pitimbu
# Processing Record 6 of Set 8 | mahajanga
# Processing Record 7 of Set 8 | grand gaube
# Processing Record 8 of Set 8 | tazovskiy
# Processing Record 9 of Set 8 | tynda
# Processing Record 10 of Set 8 | itoman
# Processing Record 11 of Set 8 | ixtapa
# Processing Record 12 of Set 8 | lethem
# Processing Record 13 of Set 8 | emerald
# Processing Record 14 of Set 8 | altay
# Processing Record 15 of Set 8 | yulara
# Processing Record 16 of Set 8 | vostok
# Processing Record 17 of Set 8 | tonantins
# Processing Record 18 of Set 8 | valle de guadalupe
# Processing Record 19 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 8 | oistins
# Processing Record 21 of Set 8 | puerto ayacucho
# Processing Record 22 of Set 8 | pombas
# Processing Record 23 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 8 | quelimane
# Processing Record 25 of Set 8 | muros
# Processing Record 26 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 27 of Set 8 | vila franca do campo
# Processing Record 28 of Set 8 | baijiantan
# Processing Record 29 of Set 8 | yuncheng
# Processing Record 30 of Set 8 | arman
# Processing Record 31 of Set 8 | klyuchi
# Processing Record 32 of Set 8 | la ronge
# Processing Record 33 of Set 8 | monte alegre
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | xining
# Processing Record 36 of Set 8 | narok
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | novi
# Processing Record 39 of Set 8 | harper
# Processing Record 40 of Set 8 | egvekinot
# Processing Record 41 of Set 8 | katsuura
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | sanmenxia
# Processing Record 44 of Set 8 | dhidhdhoo
# Processing Record 45 of Set 8 | mahanoro
# Processing Record 46 of Set 8 | north bend
# Processing Record 47 of Set 8 | appingedam
# Processing Record 48 of Set 8 | upernavik
# Processing Record 49 of Set 8 | sao filipe
# Processing Record 50 of Set 8 | luang prabang
# Processing Record 1 of Set 9 | araouane
# Processing Record 2 of Set 9 | oranjemund
# Processing Record 3 of Set 9 | klaksvik
# Processing Record 4 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 9 | champerico
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | aksu
# Processing Record 8 of Set 9 | ola
# Processing Record 9 of Set 9 | buala
# Processing Record 10 of Set 9 | khovu-aksy
# Processing Record 11 of Set 9 | kampong cham
# Processing Record 12 of Set 9 | verkhnyaya inta
# Processing Record 13 of Set 9 | mayo
# Processing Record 14 of Set 9 | dedza
# Processing Record 15 of Set 9 | orlik
# Processing Record 16 of Set 9 | qui nhon
# Processing Record 17 of Set 9 | brae
# Processing Record 18 of Set 9 | salalah
# Processing Record 19 of Set 9 | florianopolis
# Processing Record 20 of Set 9 | dwarka
# Processing Record 21 of Set 9 | macau
# Processing Record 22 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 9 | san patricio
# Processing Record 24 of Set 9 | bandarbeyla
# Processing Record 25 of Set 9 | mantua
# Processing Record 26 of Set 9 | kitui
# Processing Record 27 of Set 9 | hamada
# Processing Record 28 of Set 9 | clyde river
# Processing Record 29 of Set 9 | kaitong
# Processing Record 30 of Set 9 | kalmunai
# Processing Record 31 of Set 9 | seydi
# Processing Record 32 of Set 9 | pokhara
# Processing Record 33 of Set 9 | maumere
# Processing Record 34 of Set 9 | lata
# Processing Record 35 of Set 9 | asau
# Processing Record 36 of Set 9 | ekuvukeni
# Processing Record 37 of Set 9 | sao joao da barra
# Processing Record 38 of Set 9 | koslan
# Processing Record 39 of Set 9 | maceio
# Processing Record 40 of Set 9 | vila velha
# Processing Record 41 of Set 9 | barahona
# Processing Record 42 of Set 9 | isiro
# Processing Record 43 of Set 9 | coquimbo
# Processing Record 44 of Set 9 | tabas
# Processing Record 45 of Set 9 | bekes
# Processing Record 46 of Set 9 | san blas
# Processing Record 47 of Set 9 | miles city
# Processing Record 48 of Set 9 | alofi
# Processing Record 49 of Set 9 | ballina
# Processing Record 50 of Set 9 | balkhash
# Processing Record 1 of Set 10 | natal
# Processing Record 2 of Set 10 | diffa
# Processing Record 3 of Set 10 | shiyan
# Processing Record 4 of Set 10 | rovaniemi
# Processing Record 5 of Set 10 | kang
# Processing Record 6 of Set 10 | show low
# Processing Record 7 of Set 10 | talnakh
# Processing Record 8 of Set 10 | udachnyy
# Processing Record 9 of Set 10 | taoudenni
# Processing Record 10 of Set 10 | khor
# Processing Record 11 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 12 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 10 | la uribe
# City not found. Skipping...
# Processing Record 14 of Set 10 | hermon
# Processing Record 15 of Set 10 | guntakal
# Processing Record 16 of Set 10 | saint george
# Processing Record 17 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 10 | luganville
# Processing Record 19 of Set 10 | la asuncion
# Processing Record 20 of Set 10 | north battleford
# Processing Record 21 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 10 | chontalpa
# Processing Record 23 of Set 10 | sambava
# Processing Record 24 of Set 10 | miracema do tocantins
# Processing Record 25 of Set 10 | nemuro
# Processing Record 26 of Set 10 | tairua
# Processing Record 27 of Set 10 | hualmay
# Processing Record 28 of Set 10 | makkaveyevo
# Processing Record 29 of Set 10 | biritiba-mirim
# Processing Record 30 of Set 10 | axim
# Processing Record 31 of Set 10 | kavieng
# Processing Record 32 of Set 10 | linxia
# Processing Record 33 of Set 10 | cumbum
# Processing Record 34 of Set 10 | gambela
# Processing Record 35 of Set 10 | locharbriggs
# Processing Record 36 of Set 10 | hede
# Processing Record 37 of Set 10 | barcelona
# Processing Record 38 of Set 10 | ponta do sol
# Processing Record 39 of Set 10 | urusha
# Processing Record 40 of Set 10 | halifax
# Processing Record 41 of Set 10 | zhigansk
# Processing Record 42 of Set 10 | kuusamo
# Processing Record 43 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 10 | ponta delgada
# Processing Record 45 of Set 10 | tutoia
# Processing Record 46 of Set 10 | sudbury
# Processing Record 47 of Set 10 | sorland
# Processing Record 48 of Set 10 | bonavista
# Processing Record 49 of Set 10 | saint-joseph
# Processing Record 50 of Set 10 | tommot
# Processing Record 1 of Set 11 | ca mau
# Processing Record 2 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 11 | hobyo
# Processing Record 4 of Set 11 | oga
# Processing Record 5 of Set 11 | petropavlivka
# Processing Record 6 of Set 11 | poum
# Processing Record 7 of Set 11 | pimentel
# Processing Record 8 of Set 11 | le pradet
# Processing Record 9 of Set 11 | sao joao de pirabas
# Processing Record 10 of Set 11 | saurimo
# Processing Record 11 of Set 11 | kutum
# Processing Record 12 of Set 11 | naryan-mar
# Processing Record 13 of Set 11 | leningradskiy
# Processing Record 14 of Set 11 | biggar
# Processing Record 15 of Set 11 | lasa
# Processing Record 16 of Set 11 | marawi
# Processing Record 17 of Set 11 | alice springs
# Processing Record 18 of Set 11 | magaria
# Processing Record 19 of Set 11 | port macquarie
# Processing Record 20 of Set 11 | listvyanka
# Processing Record 21 of Set 11 | antsohihy
# Processing Record 22 of Set 11 | raudeberg
# Processing Record 23 of Set 11 | drexel heights
# Processing Record 24 of Set 11 | portland
# Processing Record 25 of Set 11 | harlingen
# Processing Record 26 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 27 of Set 11 | the valley
# Processing Record 28 of Set 11 | saint-pierre
# Processing Record 29 of Set 11 | carballo
# Processing Record 30 of Set 11 | yelatma
# Processing Record 31 of Set 11 | coahuayana
# Processing Record 32 of Set 11 | dubbo
# Processing Record 33 of Set 11 | westlake village
# Processing Record 34 of Set 11 | turochak
# Processing Record 35 of Set 11 | hammerfest
# Processing Record 36 of Set 11 | amurzet
# Processing Record 37 of Set 11 | diu
# Processing Record 38 of Set 11 | aksay
# Processing Record 39 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 40 of Set 11 | road town
# Processing Record 41 of Set 11 | wewak
# Processing Record 42 of Set 11 | palmer
# Processing Record 43 of Set 11 | clarence town
# Processing Record 44 of Set 11 | ahuimanu
# Processing Record 45 of Set 11 | chapada dos guimaraes
# Processing Record 46 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 11 | hereford
# Processing Record 48 of Set 11 | broken hill
# Processing Record 49 of Set 11 | darhan
# Processing Record 50 of Set 11 | tokur
# Processing Record 1 of Set 12 | tuatapere
# Processing Record 2 of Set 12 | sisimiut
# Processing Record 3 of Set 12 | san matias
# Processing Record 4 of Set 12 | jiaojiang
# Processing Record 5 of Set 12 | irupi
# Processing Record 6 of Set 12 | soltsy
# Processing Record 7 of Set 12 | evensk
# Processing Record 8 of Set 12 | poprad
# Processing Record 9 of Set 12 | palmeiras de goias
# Processing Record 10 of Set 12 | zeya
# Processing Record 11 of Set 12 | trincomalee
# Processing Record 12 of Set 12 | goderich
# Processing Record 13 of Set 12 | inhambane
# Processing Record 14 of Set 12 | ferrol
# Processing Record 15 of Set 12 | bontang
# Processing Record 16 of Set 12 | mozarlandia
# Processing Record 17 of Set 12 | hay river
# Processing Record 18 of Set 12 | high level
# Processing Record 19 of Set 12 | killarney
# Processing Record 20 of Set 12 | garachine
# Processing Record 21 of Set 12 | atbasar
# Processing Record 22 of Set 12 | uyuni
# Processing Record 23 of Set 12 | okato
# Processing Record 24 of Set 12 | spirit river
# Processing Record 25 of Set 12 | ajdabiya
# Processing Record 26 of Set 12 | madimba
# Processing Record 27 of Set 12 | kasempa
# Processing Record 28 of Set 12 | kuytun
# Processing Record 29 of Set 12 | amahai
# Processing Record 30 of Set 12 | suffolk
# Processing Record 31 of Set 12 | stanger
# Processing Record 32 of Set 12 | homer
# Processing Record 33 of Set 12 | toppenish
# Processing Record 34 of Set 12 | cherskiy
# Processing Record 35 of Set 12 | ust-kulom
# Processing Record 36 of Set 12 | ebbs
# Processing Record 37 of Set 12 | mormugao
# Processing Record 38 of Set 12 | abbotsford
# Processing Record 39 of Set 12 | maragogi
# Processing Record 40 of Set 12 | lang son
# Processing Record 41 of Set 12 | tecoanapa
# Processing Record 42 of Set 12 | kasangulu
# Processing Record 43 of Set 12 | weligama
# Processing Record 44 of Set 12 | romodanovo
# Processing Record 45 of Set 12 | kattivakkam
# Processing Record 46 of Set 12 | kazachinskoye
# Processing Record 47 of Set 12 | port blair
# Processing Record 48 of Set 12 | camacupa
# Processing Record 49 of Set 12 | berlevag
# Processing Record 50 of Set 12 | riviere-au-renard
# Processing Record 1 of Set 13 | palu
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | wenatchee
# Processing Record 4 of Set 13 | voh
# Processing Record 5 of Set 13 | yeppoon
# Processing Record 6 of Set 13 | sinnamary
# Processing Record 7 of Set 13 | avera
# Processing Record 8 of Set 13 | gubkinskiy
# Processing Record 9 of Set 13 | elko
# Processing Record 10 of Set 13 | padang
# Processing Record 11 of Set 13 | yumen
# Processing Record 12 of Set 13 | zheleznodorozhnyy
# Processing Record 13 of Set 13 | cam ranh
# Processing Record 14 of Set 13 | mbaiki
# Processing Record 15 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 16 of Set 13 | pedernales
# Processing Record 17 of Set 13 | hami
# Processing Record 18 of Set 13 | baker city
# Processing Record 19 of Set 13 | viru
# Processing Record 20 of Set 13 | nuoro
# Processing Record 21 of Set 13 | bathsheba
# Processing Record 22 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 23 of Set 13 | sorong
# Processing Record 24 of Set 13 | herat
# Processing Record 25 of Set 13 | luderitz
# Processing Record 26 of Set 13 | khani
# Processing Record 27 of Set 13 | severo-kurilsk
# Processing Record 28 of Set 13 | cabangahan
# Processing Record 29 of Set 13 | simbahan
# Processing Record 30 of Set 13 | gilgit
# Processing Record 31 of Set 13 | muradnagar
# Processing Record 32 of Set 13 | peniche
# Processing Record 33 of Set 13 | tavda
# Processing Record 34 of Set 13 | gravdal
# Processing Record 35 of Set 13 | faya
# Processing Record 36 of Set 13 | dunedin
# Processing Record 37 of Set 13 | de aar
# Processing Record 38 of Set 13 | balkanabat
# Processing Record 39 of Set 13 | indramayu
# Processing Record 40 of Set 13 | lincoln
# Processing Record 41 of Set 13 | churapcha
# Processing Record 42 of Set 13 | mareeba
# Processing Record 43 of Set 13 | monteagudo
# Processing Record 44 of Set 13 | adeje
# Processing Record 45 of Set 13 | anapskaya
# Processing Record 46 of Set 13 | ouadda
# Processing Record 47 of Set 13 | vegreville
# Processing Record 48 of Set 13 | batagay-alyta
# Processing Record 49 of Set 13 | luwuk
# Processing Record 50 of Set 13 | jaguarari
# Processing Record 1 of Set 14 | erzin
# Processing Record 2 of Set 14 | yeniseysk
# Processing Record 3 of Set 14 | banda aceh
# Processing Record 4 of Set 14 | jaipur hat
# City not found. Skipping...
# Processing Record 5 of Set 14 | praia
# Processing Record 6 of Set 14 | bubaque
# Processing Record 7 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 8 of Set 14 | ati
# Processing Record 9 of Set 14 | taldan
# Processing Record 10 of Set 14 | tahara
# Processing Record 11 of Set 14 | nanortalik
# Processing Record 12 of Set 14 | gamba
# Processing Record 13 of Set 14 | colomba
# Processing Record 14 of Set 14 | jalu
# Processing Record 15 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 17 of Set 14 | dicabisagan
# Processing Record 18 of Set 14 | anchorage
# Processing Record 19 of Set 14 | ulundi
# Processing Record 20 of Set 14 | svetlogorsk
# Processing Record 21 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 14 | grand-santi
# Processing Record 23 of Set 14 | ampanihy
# Processing Record 24 of Set 14 | skibbereen
# Processing Record 25 of Set 14 | rizhao
# Processing Record 26 of Set 14 | ternate
# Processing Record 27 of Set 14 | tornabe
# Processing Record 28 of Set 14 | chandpur
# Processing Record 29 of Set 14 | lerwick
# Processing Record 30 of Set 14 | kroya
# Processing Record 31 of Set 14 | borba
# Processing Record 32 of Set 14 | horsham
# Processing Record 33 of Set 14 | bowen
# Processing Record 34 of Set 14 | sungaipenuh
# Processing Record 35 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 36 of Set 14 | port augusta
# Processing Record 37 of Set 14 | okha
# Processing Record 38 of Set 14 | oyama
# Processing Record 39 of Set 14 | shitanjing
# Processing Record 40 of Set 14 | powell
# Processing Record 41 of Set 14 | behbahan
# Processing Record 42 of Set 14 | praia da vitoria
# Processing Record 43 of Set 14 | kasihan
# Processing Record 44 of Set 14 | rostock
# Processing Record 45 of Set 14 | awjilah
# Processing Record 46 of Set 14 | majholi
# Processing Record 47 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 14 | beira
# Processing Record 49 of Set 14 | channel-port aux basques
# Processing Record 50 of Set 14 | tarko-sale
# Processing Record 1 of Set 15 | kimberley
# Processing Record 2 of Set 15 | rawson
# Processing Record 3 of Set 15 | teya
# Processing Record 4 of Set 15 | lusambo
# Processing Record 5 of Set 15 | borgo san dalmazzo
# Processing Record 6 of Set 15 | dafeng
# Processing Record 7 of Set 15 | puerto escondido
# Processing Record 8 of Set 15 | scottsbluff
# Processing Record 9 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 15 | crotone
# Processing Record 11 of Set 15 | severo-yeniseyskiy
# Processing Record 12 of Set 15 | pemberton
# Processing Record 13 of Set 15 | tigil
# Processing Record 14 of Set 15 | manokwari
# Processing Record 15 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 15 | jeremie
# Processing Record 17 of Set 15 | chegem
# Processing Record 18 of Set 15 | solana beach
# Processing Record 19 of Set 15 | mangai
# Processing Record 20 of Set 15 | labuhan
# Processing Record 21 of Set 15 | sapele
# Processing Record 22 of Set 15 | dipkarpaz
# City not found. Skipping...
# Processing Record 23 of Set 15 | marfino
# Processing Record 24 of Set 15 | coihaique
# Processing Record 25 of Set 15 | peski
# Processing Record 26 of Set 15 | pangody
# Processing Record 27 of Set 15 | carbonia
# Processing Record 28 of Set 15 | kurilsk
# Processing Record 29 of Set 15 | athabasca
# Processing Record 30 of Set 15 | mpika
# Processing Record 31 of Set 15 | tilichiki
# Processing Record 32 of Set 15 | polunochnoye
# Processing Record 33 of Set 15 | volosovo
# Processing Record 34 of Set 15 | safaga
# Processing Record 35 of Set 15 | puerto carreno
# Processing Record 36 of Set 15 | liaozhong
# Processing Record 37 of Set 15 | tubuala
# Processing Record 38 of Set 15 | camalu
# Processing Record 39 of Set 15 | havre-saint-pierre
# Processing Record 40 of Set 15 | buraydah
# Processing Record 41 of Set 15 | thunder bay
# Processing Record 42 of Set 15 | namtsy
# Processing Record 43 of Set 15 | manama
# Processing Record 44 of Set 15 | worthington
# Processing Record 45 of Set 15 | meulaboh
# Processing Record 46 of Set 15 | katobu
# Processing Record 47 of Set 15 | dzhuryn
# Processing Record 48 of Set 15 | kulhudhuffushi
# Processing Record 49 of Set 15 | kupang
# Processing Record 50 of Set 15 | maibong
# Processing Record 1 of Set 16 | foumban
# Processing Record 2 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 16 | gushikawa
# Processing Record 4 of Set 16 | temaraia
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# make a get request
city_weather = requests.get(city_url)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Umm Kaddadah      SD  13.6017   26.6876    289.61        31           0
# 1   Punta Arenas      CL -53.1500  -70.9167    288.15        44          20
# 2    Pangnirtung      CA  66.1451  -65.7125    264.15        73          75
# 3     Rio Grande      BR -32.0350  -52.0986    302.15        51           0
# 4  Dzerzhinskoye      RU  56.8344   95.2283    266.01        96          99
# 5    Southampton      GB  50.9040   -1.4043    278.71        86         100
# 6        Sakakah      SA  29.9697   40.2064    283.15        71           0
# 7     Bredasdorp      ZA -34.5322   20.0403    293.15        77          96
# 8        Masindi      UG   1.6744   31.7150    295.77        33          13
# 9          Kapaa      US  22.0752 -159.3190    296.15        49           1
#
#    Wind Speed Current Description
# 0        5.95           clear sky
# 1        9.77          few clouds
# 2        1.03       broken clouds
# 3        3.60           clear sky
# 4        2.39     overcast clouds
# 5        2.24          light rain
# 6        4.12           clear sky
# 7        2.06     overcast clouds
# 8        1.58          few clouds
# 9        2.06           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Databasecities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
